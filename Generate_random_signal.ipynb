# %%
import numpy as np
import matplotlib.pyplot as plt
sound = np.random.normal(0, 5, 100)

plt.figure(figsize=(10,5))
plt.stem(sound)
plt.xlabel('Time')
plt.ylim([-10,10])
plt.ylabel('Amplitude')
plt.title('Random signal')
plt.show()
